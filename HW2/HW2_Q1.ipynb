# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_credit = pd.read_csv('/content/drive/MyDrive/Data Mining/HW2/credit cards.csv')
df_credit.head()
# Out:
#    limit_bal  sex  education  marriage   age  pay_1  pay_2  pay_3  pay_4  \
# 0    20000.0  2.0        2.0       1.0  24.0    2.0    2.0   -1.0   -1.0
# 1   120000.0  2.0        2.0       2.0  26.0   -1.0    2.0    0.0    0.0
# 2    90000.0  2.0        2.0       2.0  34.0    0.0    0.0    0.0    0.0
# 3    50000.0  2.0        2.0       1.0  37.0    0.0    0.0    0.0    0.0
# 4    50000.0  1.0        2.0       1.0  57.0   -1.0    0.0   -1.0    0.0
#
#    pay_5  ...  bill_amt4  bill_amt5  bill_amt6  pay_amt1  pay_amt2  pay_amt3  \
# 0   -2.0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1    0.0  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2    0.0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3    0.0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4    0.0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    pay_amt4  pay_amt5  pay_amt6  default
# ...

# %% [markdown]
# # Part a

# %%
fig, ax = plt.subplots(figsize=(18, 10))
corr = df_credit.corr()
sns.heatmap(corr, annot = True, ax=ax)

# %% [markdown]
# # Part b

# %%
df_new = df_credit.iloc[:, 11:17]
df_new.head()
# Out:
#    bill_amt1  bill_amt2  bill_amt3  bill_amt4  bill_amt5  bill_amt6
# 0     3913.0     3102.0      689.0        0.0        0.0        0.0
# 1     2682.0     1725.0     2682.0     3272.0     3455.0     3261.0
# 2    29239.0    14027.0    13559.0    14331.0    14948.0    15549.0
# 3    46990.0    48233.0    49291.0    28314.0    28959.0    29547.0
# 4     8617.0     5670.0    35835.0    20940.0    19146.0    19131.0

# %%
sns.pairplot(df_new)

# %% [markdown]
# # Part c

# %%
fig, ax = plt.subplots(figsize=(18, 10))
corr1 = df_credit.corr(method='spearman')
sns.heatmap(corr1, annot = True, ax=ax)

# %%
corr1['default']
# Out:
# limit_bal   -0.169586
# sex         -0.039961
# education    0.044369
# marriage    -0.026490
# age          0.005149
# pay_1        0.292213
# pay_2        0.216919
# pay_3        0.194771
# pay_4        0.173690
# pay_5        0.159043
# pay_6        0.142523
# bill_amt1   -0.025327
# bill_amt2   -0.015554
# bill_amt3   -0.012670
# bill_amt4   -0.008357
# bill_amt5   -0.006851
# bill_amt6   -0.000076
# pay_amt1    -0.160493
# pay_amt2    -0.150977
# pay_amt3    -0.139388
# pay_amt4    -0.127979
# pay_amt5    -0.116587
# pay_amt6    -0.121444
# default      1.000000
# Name: default, dtype: float64

# %% [markdown]
# # Part d

# %%
fig, ax = plt.subplots(figsize=(18, 10))
corr2 = df_credit.corr(method='kendall')
sns.heatmap(corr2, annot = True, ax=ax)

# %%
corr2['default']
# Out:
# limit_bal   -0.141088
# sex         -0.039961
# education    0.042070
# marriage    -0.026330
# age          0.004273
# pay_1        0.267885
# pay_2        0.201556
# pay_3        0.181077
# pay_4        0.162047
# pay_5        0.148829
# pay_6        0.133028
# bill_amt1   -0.020724
# bill_amt2   -0.012741
# bill_amt3   -0.010389
# bill_amt4   -0.006859
# bill_amt5   -0.005629
# bill_amt6   -0.000063
# pay_amt1    -0.133076
# pay_amt2    -0.125263
# pay_amt3    -0.116012
# pay_amt4    -0.106797
# pay_amt5    -0.097453
# pay_amt6    -0.101760
# default      1.000000
# Name: default, dtype: float64

# %% [markdown]
# # Part e --> Refer to the PDF file
